# %% [markdown]
# # 01 — Python Fundamentals
#
# ## Learning goals
# - Understand variables, basic data types, and expressions
# - Practice input/output and type conversion
# - Write simple control flow

# %%
# Arithmetic and string formatting
x, y = 12, 5
print("Addition:", x + y)
print("Division:", x / y)
print("Floor division:", x // y)
print("Power:", x ** y)

# Define name and age
name = "Alice"
age = 30

print(f"{name} is {age} years old.")
# Out:
# Addition: 17
# Division: 2.4
# Floor division: 2
# Power: 248832
# Alice is 30 years old.

# %%
# Practice task:
# 1) Create variables for your favorite number and city
favorite_number = 7
city = "Paris"

# 2) Print a sentence that combines both
print(f"My favorite number is {favorite_number} and I love the city of {city}.")
# Out:
# My favorite number is 7 and I love the city of Paris.
