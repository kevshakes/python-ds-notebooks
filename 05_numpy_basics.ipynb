# %% [markdown]
# # 05 — NumPy Basics
#
# ## Learning goals
# - Create and manipulate arrays
# - Perform vectorized math
# - Understand axis-based operations

# %%
# !python -m pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.2-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 2.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/12.3 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/12.3 MB 2.0 MB/s eta 0:00:06
#    ------ --------------------------------- 2.1/12.3 MB 2.0 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.3 MB 1.9 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.3 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.3 MB 2.2 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.3 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.3 MB 2.4 MB/s eta 0:00:04
#    --------------- ------------------------ 4.7/12.3 MB 2.0 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.3 MB 2.3 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.3 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.3 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.3 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.3/12.3 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.6/12.3 MB 2.1 MB/s eta 0:00:03
#    -------------------------- ------------- 8.1/12.3 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.3 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.3 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.3 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 10.0/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.5/12.3 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.5/12.3 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 1.5 MB/s  0:00:08
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\Administrator\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Std:", arr.std())
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Std: 1.4142135623730951

# %%
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print("Matrix:", matrix)
print("Column sums:", matrix.sum(axis=0))
print("Row sums:", matrix.sum(axis=1))
# Out:
# Matrix: [[1 2 3]
#  [4 5 6]]
# Column sums: [5 7 9]
# Row sums: [ 6 15]

# %%
# Practice task:
# Generate 100 random numbers and compute min, max, mean.

import numpy as np
np.random.seed(0)
nums = np.random.rand(100)
print("Min:", nums.min())
print("Max:", nums.max())
print("Mean:", nums.mean())
# Out:
# Min: 0.004695476192547066
# Max: 0.9883738380592262
# Mean: 0.4727938395125177
